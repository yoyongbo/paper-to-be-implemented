# %%
import pandas as pd
import os
from os import path
import matplotlib.pyplot as plt
import cv2 as cv

# %%
dir_path = '../Data_Deschaintre18/'

# %%
train_xml = path.join(dir_path,'train.xml')

# %%
train = pd.read_xml(train_xml)

# %%
train.shape
# Out:
# (199069, 19)

# %%
train.head()
# Out:
#                                                image  lightPower  lightXPos  \
# 0  /data/graphdeco/user/vdeschai/Data/Pix2Pixes/F...        2385   0.161912
# 1  /data/graphdeco/user/vdeschai/Data/Pix2Pixes/F...        2385  -0.175412
# 2  /data/graphdeco/user/vdeschai/Data/Pix2Pixes/F...        2386  -0.216049
# 3  /data/graphdeco/user/vdeschai/Data/Pix2Pixes/F...        2386  -0.314646
# 4  /data/graphdeco/user/vdeschai/Data/Pix2Pixes/F...        2417  -0.130000
#
#    lightYPos  lightZPos  camXPos  camYPos  camZPos  \
# 0   0.346538      2.197        0        0    2.146
# 1   0.302146      2.197        0        0    2.146
# 2   0.217063      2.197        0        0    2.146
# 3  -0.047064      2.197        0        0    2.146
# 4  -0.209490      2.197        0        0    2.146
#
#                                           diffuseMap  \
# 0  /data/graphdeco/user/vdeschai/Data/Flat/SoftSh...
# 1  /data/graphdeco/user/vdeschai/Data/Flat/SoftSh...
# ...

# %%
list(train.columns)
# Out:
# ['image',
#  'lightPower',
#  'lightXPos',
#  'lightYPos',
#  'lightZPos',
#  'camXPos',
#  'camYPos',
#  'camZPos',
#  'diffuseMap',
#  'localNormalMap',
#  'globalNormalMap',
#  'roughnessMap',
#  'specularMap',
#  'geoNormalMap',
#  'uvscale',
#  'uoffset',
#  'voffset',
#  'rotation',
#  'identifier']

# %%
train['image'][0]
# Out:
# '/data/graphdeco/user/vdeschai/Data/Pix2Pixes/Flat/BlendedSoftShadowsFOV/trainBlended/0000001;Fabric_Suit_VintageXrocks_dirt_ground;11X1.png'

# %%
train['localNormalMap'][0]
# Out:
# '/data/graphdeco/user/vdeschai/Data/Flat/SoftShadingBlendedLargerFOV/trainBlended/flat;Fabric_Suit_VintageXrocks_dirt_ground;11X1;1;0;2;0;localNormal.png'

# %%
img = cv.imread(path.join(dir_path,'trainBlended/0000001;Fabric_Suit_VintageXrocks_dirt_ground;11X1.png'))
plt.imshow(img)

# %%
img2 = cv.imread(path.join(dir_path,'trainBlended/flat;Fabric_Suit_VintageXrocks_dirt_ground;11X1;1;0;2;0;localNormal.png'))
plt.imshow(img)
